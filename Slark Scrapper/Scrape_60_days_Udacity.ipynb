# %% [markdown]
# # Scraping Slark 60 Days of Udacity Data
#
#
# <br/><br/> Import the show stopper library, BeautifulSoup, along with others.

# %%
# Import  things worth importing

# The Showstopper
from bs4 import BeautifulSoup 
# The usual chaddi-buddies 
import numpy as np
import pandas as pd
# Writers 
import csv

# Some debugging jing-bang 
_GLOBAL_DEBUG_ = True

# %% [markdown]
#  ### Reading the HTML Page
# We open the html file for parsing. Notice the `_encoding='utf-8', errors='ignore'_` parameters passed along with the open() command. This will ensure that we don't run into any encoding related issues while parsing.

# %%
# Open the HTML file for June and create a BeautifulSoup Object
with open('./data/June_Corpus.html', encoding='utf-8', errors='ignore') as f:
    contents = f.read()
    page_content = BeautifulSoup(contents, 'lxml')

# %%
# Warming Up 
print(len(page_content))
print(page_content.head.meta)
print(page_content.head.title)
print(page_content.head.title.get_text())
# Out:
# 3
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>
#
# #60daysofudacity (June 2019) - Secure &amp; Private AI Challenge Course (Public) -
# Slarck
#
#
# </title>
#
#
# #60daysofudacity (June 2019) - Secure & Private AI Challenge Course (Public) -
# Slarck

# %% [markdown]
# ### Finding the Tags
# The chat details are buried inside a labyrinth of HTML tags, with the last one being
# > `_div class = "chat-wrapper chat-SL"_`
#
# <br/>Inside this parent _div_, there are two kinds of divs that hold information, and they are both at the same level.
# 1. `_div class = "chat-msg-chrome"_` --> Contains data about Username and Timestamp
# 2. `_div class = "chat-msg"_` --> Contains the message posted by the user
#
# <br/>We want to parse the data into a dictionary that would look like,
# > `raw_data_dict { 'timestamp': _TIME_, 'username': _Pranjal_, 'messages': _[ 'List', 'of', 'messages' ]_ }`
#
# <br/>Problem we face here is that if a user posted two or more messages (they broke their messages in smaller pieces) back to back, there can be two or more `_chat-msg_` divs. So we cannot simply index `_chat-msg-chrome_` and `_chat-msg_` and assume that they'll match.
#
# <br/>A simple parsing algorithm in this could look like,
# > Loop over children of `_div class = 'chat-wrapper chat-SL'`_
# >> extract Username and Timestamp from `_chat-msg-chrome_`
# >> Loop over `_chat-msg_` divs
# >>> extract chat message data <br/>
# >>> break the inner loop as soon as you hit another `_chat-wrapper chat-SL_`
#
# <br/>To test our algorithm, let's first try it out on a smaller subset of data that is manageable and easier to debug.

# %%
# Let's do a find_all and limit the tags it finds
# So that its easy to analyse the results 
for tag in page_content.find_all(class_=['chat-msg-chrome','chat-msg'], limit=50):
    print(tag.prettify())
# Out:
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/636018085989_befa8273275ecfbdb596_72.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     akshit
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 4:58 p.m.">
#     16:58
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @akshit
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/0142ed5ea0e340d6fe0df3ba8331e1da.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     aleksandra.mozejko
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 5:07 p.m.">
#     17:07
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @aleksandra.mozejko
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/650354705204_1f23210cc53acac51ca8_72.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     161210032
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 5:09 p.m.">
#     17:09
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @161210032
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @161210032
#   </strong>
#   set the channel topic: Posting your daily report of your project
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div class="chat-att">
#   <blockquote style="border-left-color: #D0D0D0">
#    <div>
#     <strong>
#      @akshit
#     </strong>
#     if you can make all the memebers admin for a channel we can directly post out git commits in that channel through slack bot , I suppose you will look into this as we have
#     <strong>
#      #60daysofudacity
#     </strong>
#     <br/>
#    </div>
#   </blockquote>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/e0be7138a2fa0e2a69db8da786d03a0b.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     ziad.esam.ezat
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 5:26 p.m.">
#     17:26
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @ziad.esam.ezat
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @161210032
#   </strong>
#   Isn't there a way we can post git commits through slack bot without us being channel admins?
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   That's a good idea but if channel admins can delete the channel it'd be rather risky.
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/650354705204_1f23210cc53acac51ca8_72.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     161210032
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 5:40 p.m.">
#     17:40
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @ziad.esam.ezat
#   </strong>
#   No , i didn't find a way . if
#   <strong>
#    @akshit
#   </strong>
#   can help in finding a automated way , it would be really helpful .
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/15d738cdb631d961c7ac2d4845776c3b.jpeg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     rekha.chandrasekaran2
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 5:44 p.m.">
#     17:44
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @rekha.chandrasekaran2
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/0142ed5ea0e340d6fe0df3ba8331e1da.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     aleksandra.mozejko
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 5:49 p.m.">
#     17:49
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @aleksandra.mozejko
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/d655edc52393bfade70944e7af8f5129.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     abhinav.raj116
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 6:23 p.m.">
#     18:23
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @abhinav.raj116
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   This is my first time to be a part of udacity. Can someone explain me what is 60 days of udacity?
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/78c641dcb41e87b93c99e1ea1020c34e.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     rupeshpurum
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 6:47 p.m.">
#     18:47
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @rupeshpurum
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/ef4cf33776a418092bec2fecd3149534.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     amatseshe
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 6:53 p.m.">
#     18:53
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @amatseshe
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   I'm excited for 60 days of Udacity
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/a0c304a37fe0e90511bfe9dfe8e82956.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     smogal95
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 7:44 p.m.">
#     19:44
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @smogal95
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/b2d0a20e50cabf88bd8defea467f14b5.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     garg4.ag
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 7:56 p.m.">
#     19:56
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @garg4.ag
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/8a7497c7c91ac9b0067a1d3a457a7a18.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     ishgirwan
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 7:58 p.m.">
#     19:58
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @ishgirwan
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/24d5cf56baee6d1de5a16997c2e98262.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     mmaaz0786
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 8:01 p.m.">
#     20:01
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @mmaaz0786
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/c9d35f3cf88a3b890e590817277472b8.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     rajput.gaurav8341
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 11:11 p.m.">
#     23:11
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @rajput.gaurav8341
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/644315233521_5d3ad245da587ad1fdf2_72.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     labknr98
#    </span>
#    <span class="chat-msg-ts" title="06/21/2019 11:48 p.m.">
#     23:48
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @labknr98
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/650693150212_ee7b474b415f3ce9081d_72.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     ferdib.bsmrstu
#    </span>
#    <span class="chat-msg-ts" title="06/22/2019 1:13 a.m.">
#     01:13
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @ferdib.bsmrstu
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/6891ffc49c32d7fdce563718740b3bd6.jpeg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     lspironello
#    </span>
#    <span class="chat-msg-ts" title="06/22/2019 1:28 a.m.">
#     01:28
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @lspironello
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/02a3d16aa9a32f8d612e92011a897301.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     sridhar_ethiraj
#    </span>
#    <span class="chat-msg-ts" title="06/22/2019 1:28 a.m.">
#     01:28
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @sridhar_ethiraj
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/fb484fb49378a7c4dd538f161663171d.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     adi.kul30
#    </span>
#    <span class="chat-msg-ts" title="06/22/2019 1:28 a.m.">
#     01:28
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @adi.kul30
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/26da1ba047298c542160c682e304f298.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     ewotawa
#    </span>
#    <span class="chat-msg-ts" title="06/22/2019 1:28 a.m.">
#     01:28
#    </span>
#   </div>
#  </div>
# </div>
#
# <div class="chat-msg">
#  <div>
#   <strong>
#    @ewotawa
#   </strong>
#   has joined the channel
#   <br/>
#  </div>
# </div>
#
# <div class="chat-msg-chrome">
#  <div class="chat-msg-avatar">
#   <img src="./June_Corpus_files/641336872643_10b15ec6c8be6a600e0f_72.jpg"/>
#  </div>
#  <div class="chat-msg-content">
#   <div class="chat-msg-topline">
#    <span class="chat-msg-auth">
#     jessie_lee_dn
#    </span>
#    <span class="chat-msg-ts" title="06/22/2019 1:28 a.m.">
#     01:28
#    </span>
#   </div>
#  </div>
# </div>

# %% [markdown]
# ### Extracting Text
# The above results are a big relief. It can be seen that passing the respective div tags as a list and then looping over the response results in data being parsed sequentially. Therefore, we can now have a simple _if_ condition that aligns the data to its respective key in the dictionary.
#
# <br/>Also, at this stage we will be keeping the structure of the dictionary very simple.
# > `super_raw_data_dict = { 'username': _Relevant Data_, 'chat-msg': _Relevant Data_ }`

# %%
# Let's loop over the previous data again and see if we can parse it into 
# Different categories

for tag in page_content.find_all(class_=['chat-msg-chrome','chat-msg'], limit=50):
    # Let's extract the username from the chat-msg-chrome div
    if tag['class'] == ['chat-msg-chrome']:
        print('AUTH MSG ' + tag.find(class_ = 'chat-msg-auth').get_text())
        # Now try extracting the timestamp as well 
        print(tag.find(class_ = 'chat-msg-ts')['title'])
    elif tag['class'] == ['chat-msg']:
        # Let's see if we can get the chat message as well 
        print('CHAT MSG ' + tag.get_text())
# Out:
# AUTH MSG akshit
# 06/21/2019 4:58 p.m.
# CHAT MSG
# @akshit has joined the channel
#
# CHAT MSG
#
# AUTH MSG aleksandra.mozejko
# 06/21/2019 5:07 p.m.
# CHAT MSG
# @aleksandra.mozejko has joined the channel
#
# AUTH MSG 161210032
# 06/21/2019 5:09 p.m.
# CHAT MSG
# @161210032 has joined the channel
#
# CHAT MSG
# @161210032 set the channel topic: Posting your daily report of your project
#
# CHAT MSG
# @akshit if you can make all the memebers admin for a channel we can directly post out git commits in that channel through slack bot , I suppose you will look into this as we have #60daysofudacity
#
# AUTH MSG ziad.esam.ezat
# 06/21/2019 5:26 p.m.
# CHAT MSG
# @ziad.esam.ezat has joined the channel
#
# CHAT MSG
# @161210032 Isn't there a way we can post git commits through slack bot without us being channel admins?
#
# CHAT MSG
# That's a good idea but if channel admins can delete the channel it'd be rather risky.
#
# AUTH MSG 161210032
# 06/21/2019 5:40 p.m.
# CHAT MSG
# @ziad.esam.ezat No , i didn't find a way . if @akshit can help in finding a automated way , it would be really helpful .
#
# AUTH MSG rekha.chandrasekaran2
# 06/21/2019 5:44 p.m.
# CHAT MSG
# @rekha.chandrasekaran2 has joined the channel
#
# AUTH MSG aleksandra.mozejko
# 06/21/2019 5:49 p.m.
# CHAT MSG
# @aleksandra.mozejko has joined the channel
#
# AUTH MSG abhinav.raj116
# 06/21/2019 6:23 p.m.
# CHAT MSG
# @abhinav.raj116 has joined the channel
#
# CHAT MSG
# This is my first time to be a part of udacity. Can someone explain me what is 60 days of udacity?
#
# AUTH MSG rupeshpurum
# 06/21/2019 6:47 p.m.
# CHAT MSG
# @rupeshpurum has joined the channel
#
# AUTH MSG amatseshe
# 06/21/2019 6:53 p.m.
# CHAT MSG
# @amatseshe has joined the channel
#
# CHAT MSG
# I'm excited for 60 days of Udacity
#
# AUTH MSG smogal95
# 06/21/2019 7:44 p.m.
# CHAT MSG
# @smogal95 has joined the channel
#
# AUTH MSG garg4.ag
# 06/21/2019 7:56 p.m.
# CHAT MSG
# @garg4.ag has joined the channel
#
# AUTH MSG ishgirwan
# 06/21/2019 7:58 p.m.
# CHAT MSG
# @ishgirwan has joined the channel
#
# AUTH MSG mmaaz0786
# 06/21/2019 8:01 p.m.
# CHAT MSG
# @mmaaz0786 has joined the channel
#
# AUTH MSG rajput.gaurav8341
# 06/21/2019 11:11 p.m.
# CHAT MSG
# @rajput.gaurav8341 has joined the channel
#
# AUTH MSG labknr98
# 06/21/2019 11:48 p.m.
# CHAT MSG
# @labknr98 has joined the channel
#
# AUTH MSG ferdib.bsmrstu
# 06/22/2019 1:13 a.m.
# CHAT MSG
# @ferdib.bsmrstu has joined the channel
#
# AUTH MSG lspironello
# 06/22/2019 1:28 a.m.
# CHAT MSG
# @lspironello has joined the channel
#
# AUTH MSG sridhar_ethiraj
# 06/22/2019 1:28 a.m.
# CHAT MSG
# @sridhar_ethiraj has joined the channel
#
# AUTH MSG adi.kul30
# 06/22/2019 1:28 a.m.
# CHAT MSG
# @adi.kul30 has joined the channel
#
# AUTH MSG ewotawa
# 06/22/2019 1:28 a.m.
# CHAT MSG
# @ewotawa has joined the channel
#
# AUTH MSG jessie_lee_dn
# 06/22/2019 1:28 a.m.

# %% [markdown]
# ## Chat Extraction Routine
# As we can see above, I have managed to extract all the necessary information from the pages. There's something more, I don't think the dictionary oriented data structure I had imagined in the start makes sense now since the data extracted doesn't require any further HTML level preprocessing.
#
# <br/>Right now I need a data structure where I can add the sequentially and then later on perform preprocessing and munging to extract insights.
#
# <br/>You guessed it, we are going to use the Pandas Dataframe for this job.
# <br/><br/>DF Structure,
# <br/>`index   timestamp   username   message`

# %%
# Start populating the DF with raw text corpus
# If we get back to back 'chat-msg' tags, we are simply 
# Going to .join them in a single string before adding to the DF
# We initially populate DF for only 100 matches to test the output

def extract_chat(page_content, limit=None):
    """
    Extract chat message details from the HTML document.

    Parameters
    ----------
    page_content : BeautifulSoup Object  
        The HTML page object parsed by Beautiful Soup
    limit : integer
        number of matches to find in the HTML page 
        object. Default = None, find all the matches. 
        
    Returns
    -------
    df_list : list of dict
         A list of dictionaries containing the extracted 
         information about chat messages. 
         [{
             'timestamp': timestamp string,
             'username': username string,
             'message': messages
        }]
    """
    
    # We will store the data of the PREVIOUS message in these variables 
    # and push it to the df_list[] only when we find the start of a 
    # new message, i.e. 'chat-msg-chrome' tag. This ensures that we are 
    # collecting all the 'chat-msg'es in the prev_messages list before 
    # adding it to the df_list[].
    prev_timestamp = None
    prev_username = None
    prev_messages = []

    # Local debug flag
    _LOCAL_DEBUG_ = False

    # We will create a list-of-dictionaries to generate our dataframe. 
    # It is by far the FASTEST method in the world to create a DF :P 
    df_list = []
    for tag in page_content.find_all(class_=['chat-msg-chrome','chat-msg'], limit=limit):
        if tag['class'] == ['chat-msg-chrome']:
        # We are at the start of a new message, therefore
        # Add the contents of the previous message to df_list
            temp_dict = {
                'timestamp': prev_timestamp,
                'username': prev_username,
                'message': ' '.join(prev_messages)}
            df_list.append(temp_dict)

            # Check what we parsin' 
            if _GLOBAL_DEBUG_ and _LOCAL_DEBUG_: 
                print(prev_username)
                print(prev_timestamp)
                print(' '.join(prev_messages))
                print(len(' '.join(prev_messages)))
                print()

            # Add the new information to username and timestamp variables 
            prev_username = tag.find(class_ = 'chat-msg-auth').get_text()
            prev_timestamp = tag.find(class_ = 'chat-msg-ts')['title']
            # Clear up the old messages from the buffer
            prev_messages = []
        elif tag['class'] == ['chat-msg']:
            # Came across a new chat message
            # append it to prev_messages[] 
            prev_messages.append(tag.get_text())
    
    return df_list

# %%
# Extract the chat information from the HTML page object 
df_list = extract_chat(page_content, limit=100)

# Check What we got in the df_list 
print(df_list[:10])
# Out:
# [{'timestamp': None, 'username': None, 'message': ''}, {'timestamp': '06/21/2019 4:58 p.m.', 'username': 'akshit', 'message': '\n@akshit has joined the channel\n \n'}, {'timestamp': '06/21/2019 5:07 p.m.', 'username': 'aleksandra.mozejko', 'message': '\n@aleksandra.mozejko has joined the channel\n'}, {'timestamp': '06/21/2019 5:09 p.m.', 'username': '161210032', 'message': '\n@161210032 has joined the channel\n \n@161210032 set the channel topic: Posting your daily report of your project\n \n@akshit if you can make all the memebers admin for a channel we can directly post out git commits in that channel through slack bot , I suppose you will look into this as we have #60daysofudacity\n'}, {'timestamp': '06/21/2019 5:26 p.m.', 'username': 'ziad.esam.ezat', 'message': "\n@ziad.esam.ezat has joined the channel\n \n@161210032 Isn't there a way we can post git commits through slack bot without us being channel admins?\n \nThat's a good idea but if channel admins can delete the channel it'd be rather risky.\n"}, {'timestamp': '06/21/2019 5:40 p.m.', 'username': '161210032', 'message': "\n@ziad.esam.ezat No , i didn't find a way . if @akshit can help in finding a automated way , it would be really helpful .\n"}, {'timestamp': '06/21/2019 5:44 p.m.', 'username': 'rekha.chandrasekaran2', 'message': '\n@rekha.chandrasekaran2 has joined the channel\n'}, {'timestamp': '06/21/2019 5:49 p.m.', 'username': 'aleksandra.mozejko', 'message': '\n@aleksandra.mozejko has joined the channel\n'}, {'timestamp': '06/21/2019 6:23 p.m.', 'username': 'abhinav.raj116', 'message': '\n@abhinav.raj116 has joined the channel\n \nThis is my first time to be a part of udacity. Can someone explain me what is 60 days of udacity?\n'}, {'timestamp': '06/21/2019 6:47 p.m.', 'username': 'rupeshpurum', 'message': '\n@rupeshpurum has joined the channel\n'}]

# %%
# Create the god damn dataframe and go to sleep! 
raw_text_df = pd.DataFrame(df_list)
raw_text_df
# PS - Its 4:15AM in the morning!
# Out:
#                                               message              timestamp  \
# 0                                                                       None
# 1               \n@akshit has joined the channel\n \n   06/21/2019 4:58 p.m.
# 2      \n@aleksandra.mozejko has joined the channel\n   06/21/2019 5:07 p.m.
# 3   \n@161210032 has joined the channel\n \n@16121...   06/21/2019 5:09 p.m.
# 4   \n@ziad.esam.ezat has joined the channel\n \n@...   06/21/2019 5:26 p.m.
# 5   \n@ziad.esam.ezat No , i didn't find a way . i...   06/21/2019 5:40 p.m.
# 6   \n@rekha.chandrasekaran2 has joined the channel\n   06/21/2019 5:44 p.m.
# 7      \n@aleksandra.mozejko has joined the channel\n   06/21/2019 5:49 p.m.
# 8   \n@abhinav.raj116 has joined the channel\n \nT...   06/21/2019 6:23 p.m.
# 9             \n@rupeshpurum has joined the channel\n   06/21/2019 6:47 p.m.
# 10  \n@amatseshe has joined the channel\n \nI'm ex...   06/21/2019 6:53 p.m.
# 11               \n@smogal95 has joined the channel\n   06/21/2019 7:44 p.m.
# 12               \n@garg4.ag has joined the channel\n   06/21/2019 7:56 p.m.
# 13              \n@ishgirwan has joined the channel\n   06/21/2019 7:58 p.m.
# 14              \n@mmaaz0786 has joined the channel\n   06/21/2019 8:01 p.m.
# 15      \n@rajput.gaurav8341 has joined the channel\n  06/21/2019 11:11 p.m.
# 16               \n@labknr98 has joined the channel\n  06/21/2019 11:48 p.m.
# 17         \n@ferdib.bsmrstu has joined the channel\n   06/22/2019 1:13 a.m.
# 18            \n@lspironello has joined the channel\n   06/22/2019 1:28 a.m.
# 19        \n@sridhar_ethiraj has joined the channel\n   06/22/2019 1:28 a.m.
# 20              \n@adi.kul30 has joined the channel\n   06/22/2019 1:28 a.m.
# 21                \n@ewotawa has joined the channel\n   06/22/2019 1:28 a.m.
# 22          \n@jessie_lee_dn has joined the channel\n   06/22/2019 1:28 a.m.
# 23                                   \nHello world!\n   06/22/2019 1:29 a.m.
# 24               \n@mhmohona has joined the channel\n   06/22/2019 1:34 a.m.
# 25          \n@sajjadmanal24 has joined the channel\n   06/22/2019 1:34 a.m.
# 26              \nSuper excited for 60daysOfUdacity\n   06/22/2019 1:34 a.m.
# 27  \nExcited to be the part of this\n \nCan someo...   06/22/2019 1:36 a.m.
# 28      \nThe details haven't been announced yet . \n   06/22/2019 1:41 a.m.
# 29                          \nHello beautiful world\n   06/22/2019 1:49 a.m.
# 30       \n@dharmaraj.techie has joined the channel\n   06/22/2019 1:52 a.m.
# 31  \n@deepak.sharma.it.1992 has joined the channel\n   06/22/2019 1:52 a.m.
# 32  \n@jdevivaraprasadreddy7 has joined the channel\n   06/22/2019 1:52 a.m.
# 33        \n@yemissi.kifouly has joined the channel\n   06/22/2019 1:53 a.m.
# 34           \n@carlo12david has joined the channel\n   06/22/2019 1:53 a.m.
# 35  \n@mohdnaushad.12-cse-16 has joined the channel\n   06/22/2019 1:53 a.m.
# 36  \nHI @abhinav.raj116 The idea of 60 days of Ud...   06/22/2019 1:53 a.m.
# 37  \nWhoa. The start of the beautiful journey\n \...   06/22/2019 1:56 a.m.
# 38      \nSuper Excited for this Learning Venture! \n   06/22/2019 2:05 a.m.
# 39                                \nComing soon....\n   06/22/2019 2:15 a.m.
# 40    \nhttps://www.youtube.com/watch?v=dU1xS07N-FA\n   06/22/2019 2:15 a.m.
# 41  \n@akshit It would be really helpful for of us...   06/22/2019 2:19 a.m.
# 42               \nI share your concern @aisha.jv70\n   06/22/2019 2:23 a.m.
# 43               \nThe details would be shared soon\n   06/22/2019 2:37 a.m.
# 44                            \nHello how are you! \n   06/22/2019 2:39 a.m.
# 45  \nWhen will they publish details about the pro...   06/22/2019 2:40 a.m.
#
#                  username
# 0                    None
# 1                  akshit
# 2      aleksandra.mozejko
# 3               161210032
# 4          ziad.esam.ezat
# 5               161210032
# 6   rekha.chandrasekaran2
# 7      aleksandra.mozejko
# 8          abhinav.raj116
# 9             rupeshpurum
# 10              amatseshe
# 11               smogal95
# 12               garg4.ag
# 13              ishgirwan
# 14              mmaaz0786
# 15      rajput.gaurav8341
# 16               labknr98
# 17         ferdib.bsmrstu
# 18            lspironello
# 19        sridhar_ethiraj
# 20              adi.kul30
# 21                ewotawa
# 22          jessie_lee_dn
# 23                ewotawa
# 24               mhmohona
# 25          sajjadmanal24
# 26     harivamsiyadavalli
# 27            seeratpal91
# 28            sfmajors373
# 29             hugo.amaro
# 30       dharmaraj.techie
# 31  deepak.sharma.it.1992
# 32  jdevivaraprasadreddy7
# 33        yemissi.kifouly
# 34           carlo12david
# 35  mohdnaushad.12-cse-16
# 36               ltruncel
# 37          sajjadmanal24
# 38             aisha.jv70
# 39               learn556
# 40      ravikantsingh2308
# 41             aisha.jv70
# 42        arturfreitas999
# 43              ishgirwan
# 44           calincan2000
# 45            riday467366

# %% [markdown]
# ## Mild Preprocessing
# Few more things we need to do before we can parse the whole dataset to a CSV file.
# 1. Remove the first row. Due to our chat scraping method, first row in the DF is going to be full of Nulls.
# 2. Add a fresh column called `'m_length'` which will hold the length of each message. We will use this column later on when figuring out the optimum length of our training messages for the generative text AI.
# 3. Convert the timestamps in the timestamp column to real timestamps.

# %%
# Remove the first row 
raw_text_df.drop([0], axis=0, inplace=True)
# Check! 
if _GLOBAL_DEBUG_:
    print(raw_text_df.head())
# Out:
#                                              message             timestamp  \
# 1              \n@akshit has joined the channel\n \n  06/21/2019 4:58 p.m.
# 2     \n@aleksandra.mozejko has joined the channel\n  06/21/2019 5:07 p.m.
# 3  \n@161210032 has joined the channel\n \n@16121...  06/21/2019 5:09 p.m.
# 4  \n@ziad.esam.ezat has joined the channel\n \n@...  06/21/2019 5:26 p.m.
# 5  \n@ziad.esam.ezat No , i didn't find a way . i...  06/21/2019 5:40 p.m.
#
#              username
# 1              akshit
# 2  aleksandra.mozejko
# 3           161210032
# 4      ziad.esam.ezat
# 5           161210032

# %%
# Add the new column called m_length 
# Deploy Optimization EXTREME! 
raw_text_df['m_length'] = raw_text_df['message'].apply(lambda row: len(row))
raw_text_df
# Out:
#                                               message              timestamp  \
# 1               \n@akshit has joined the channel\n \n   06/21/2019 4:58 p.m.
# 2      \n@aleksandra.mozejko has joined the channel\n   06/21/2019 5:07 p.m.
# 3   \n@161210032 has joined the channel\n \n@16121...   06/21/2019 5:09 p.m.
# 4   \n@ziad.esam.ezat has joined the channel\n \n@...   06/21/2019 5:26 p.m.
# 5   \n@ziad.esam.ezat No , i didn't find a way . i...   06/21/2019 5:40 p.m.
# 6   \n@rekha.chandrasekaran2 has joined the channel\n   06/21/2019 5:44 p.m.
# 7      \n@aleksandra.mozejko has joined the channel\n   06/21/2019 5:49 p.m.
# 8   \n@abhinav.raj116 has joined the channel\n \nT...   06/21/2019 6:23 p.m.
# 9             \n@rupeshpurum has joined the channel\n   06/21/2019 6:47 p.m.
# 10  \n@amatseshe has joined the channel\n \nI'm ex...   06/21/2019 6:53 p.m.
# 11               \n@smogal95 has joined the channel\n   06/21/2019 7:44 p.m.
# 12               \n@garg4.ag has joined the channel\n   06/21/2019 7:56 p.m.
# 13              \n@ishgirwan has joined the channel\n   06/21/2019 7:58 p.m.
# 14              \n@mmaaz0786 has joined the channel\n   06/21/2019 8:01 p.m.
# 15      \n@rajput.gaurav8341 has joined the channel\n  06/21/2019 11:11 p.m.
# 16               \n@labknr98 has joined the channel\n  06/21/2019 11:48 p.m.
# 17         \n@ferdib.bsmrstu has joined the channel\n   06/22/2019 1:13 a.m.
# 18            \n@lspironello has joined the channel\n   06/22/2019 1:28 a.m.
# 19        \n@sridhar_ethiraj has joined the channel\n   06/22/2019 1:28 a.m.
# 20              \n@adi.kul30 has joined the channel\n   06/22/2019 1:28 a.m.
# 21                \n@ewotawa has joined the channel\n   06/22/2019 1:28 a.m.
# 22          \n@jessie_lee_dn has joined the channel\n   06/22/2019 1:28 a.m.
# 23                                   \nHello world!\n   06/22/2019 1:29 a.m.
# 24               \n@mhmohona has joined the channel\n   06/22/2019 1:34 a.m.
# 25          \n@sajjadmanal24 has joined the channel\n   06/22/2019 1:34 a.m.
# 26              \nSuper excited for 60daysOfUdacity\n   06/22/2019 1:34 a.m.
# 27  \nExcited to be the part of this\n \nCan someo...   06/22/2019 1:36 a.m.
# 28      \nThe details haven't been announced yet . \n   06/22/2019 1:41 a.m.
# 29                          \nHello beautiful world\n   06/22/2019 1:49 a.m.
# 30       \n@dharmaraj.techie has joined the channel\n   06/22/2019 1:52 a.m.
# 31  \n@deepak.sharma.it.1992 has joined the channel\n   06/22/2019 1:52 a.m.
# 32  \n@jdevivaraprasadreddy7 has joined the channel\n   06/22/2019 1:52 a.m.
# 33        \n@yemissi.kifouly has joined the channel\n   06/22/2019 1:53 a.m.
# 34           \n@carlo12david has joined the channel\n   06/22/2019 1:53 a.m.
# 35  \n@mohdnaushad.12-cse-16 has joined the channel\n   06/22/2019 1:53 a.m.
# 36  \nHI @abhinav.raj116 The idea of 60 days of Ud...   06/22/2019 1:53 a.m.
# 37  \nWhoa. The start of the beautiful journey\n \...   06/22/2019 1:56 a.m.
# 38      \nSuper Excited for this Learning Venture! \n   06/22/2019 2:05 a.m.
# 39                                \nComing soon....\n   06/22/2019 2:15 a.m.
# 40    \nhttps://www.youtube.com/watch?v=dU1xS07N-FA\n   06/22/2019 2:15 a.m.
# 41  \n@akshit It would be really helpful for of us...   06/22/2019 2:19 a.m.
# 42               \nI share your concern @aisha.jv70\n   06/22/2019 2:23 a.m.
# 43               \nThe details would be shared soon\n   06/22/2019 2:37 a.m.
# 44                            \nHello how are you! \n   06/22/2019 2:39 a.m.
# 45  \nWhen will they publish details about the pro...   06/22/2019 2:40 a.m.
#
#                  username  m_length
# 1                  akshit        34
# 2      aleksandra.mozejko        44
# 3               161210032       311
# 4          ziad.esam.ezat       234
# 5               161210032       122
# 6   rekha.chandrasekaran2        47
# 7      aleksandra.mozejko        44
# 8          abhinav.raj116       140
# 9             rupeshpurum        37
# 10              amatseshe        72
# 11               smogal95        34
# 12               garg4.ag        34
# 13              ishgirwan        35
# 14              mmaaz0786        35
# 15      rajput.gaurav8341        43
# 16               labknr98        34
# 17         ferdib.bsmrstu        40
# 18            lspironello        37
# 19        sridhar_ethiraj        41
# 20              adi.kul30        35
# 21                ewotawa        33
# 22          jessie_lee_dn        39
# 23                ewotawa        14
# 24               mhmohona        34
# 25          sajjadmanal24        39
# 26     harivamsiyadavalli        35
# 27            seeratpal91       127
# 28            sfmajors373        43
# 29             hugo.amaro        23
# 30       dharmaraj.techie        42
# 31  deepak.sharma.it.1992        47
# 32  jdevivaraprasadreddy7        47
# 33        yemissi.kifouly        41
# 34           carlo12david        38
# 35  mohdnaushad.12-cse-16        47
# 36               ltruncel       201
# 37          sajjadmanal24        77
# 38             aisha.jv70        43
# 39               learn556        17
# 40      ravikantsingh2308        45
# 41             aisha.jv70       167
# 42        arturfreitas999        34
# 43              ishgirwan        34
# 44           calincan2000        21
# 45            riday467366        51

# %%
# Time to fix the time column!!! 
print(raw_text_df.info())
raw_text_df['datetime'] = raw_text_df['timestamp'].astype('datetime64[ns]') 
print(raw_text_df.info())
print(raw_text_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 1 to 45
# Data columns (total 4 columns):
# message      45 non-null object
# timestamp    45 non-null object
# username     45 non-null object
# m_length     45 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 1.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 1 to 45
# Data columns (total 5 columns):
# message      45 non-null object
# timestamp    45 non-null object
# username     45 non-null object
# m_length     45 non-null int64
# datetime     45 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB
# None
#                                              message             timestamp  \
# 1              \n@akshit has joined the channel\n \n  06/21/2019 4:58 p.m.
# 2     \n@aleksandra.mozejko has joined the channel\n  06/21/2019 5:07 p.m.
# 3  \n@161210032 has joined the channel\n \n@16121...  06/21/2019 5:09 p.m.
# 4  \n@ziad.esam.ezat has joined the channel\n \n@...  06/21/2019 5:26 p.m.
# 5  \n@ziad.esam.ezat No , i didn't find a way . i...  06/21/2019 5:40 p.m.
#
#              username  m_length            datetime
# 1              akshit        34 2019-06-21 16:58:00
# 2  aleksandra.mozejko        44 2019-06-21 17:07:00
# 3           161210032       311 2019-06-21 17:09:00
# 4      ziad.esam.ezat       234 2019-06-21 17:26:00
# 5           161210032       122 2019-06-21 17:40:00

# %% [markdown]
# ### Mild Preprocessing Routine
# Looks like we are all set, ready to roll and parse the whole document in a CSV.
# Before we do that, let's make a sub-routine of the above steps and call it `mild_preprocessing`.

# %%
def mild_preprocessing(df): 
    """
    Employs a few preprocessing steps to the dataframe. 
    1. Removes the top row with Nulls
    2. Adds a new column, m_length, that contains the length 
    of the 'message'
    3. Converts the string timestamp to a recognized datetime 
    format in a new column called 'datetime'
    
    Parameters
    ----------
    df : Pandas DataFrame   
        Unprocessed dataframe
    
    Returns
    -------
    df : Post processed dataframe 
    """    
    
    # Local Debug Flag
    _LOCAL_DEBUG_ = False 
    
    # 1
    # Remove the first row 
    df.drop([0], axis=0, inplace=True)
    # 2
    # Add the new column called m_length 
    df['m_length'] = df['message'].apply(lambda row: len(row))
    # 3 
    # Fix the date column 
    # I have figured that, for some really weird and RETARDED reason, the 
    # timestamps are 'corrupted'!!!
    # Like a dumbass, the html page stamps 'midnight' or 'noon' for comments 
    # that arrive on 12:00AM or 12:00PM. This absolutely screws up the 
    # .astype('datetime64[ns]') casting and throws up an error. 
    # Therefore, need to add an additional step here to cleanse the 
    # stupid timestamping system at Slark/Slack 
    n_slice = len('noon')
    m_slice = len('midnight')
    df.loc[:, 'timestamp'] = df['timestamp'].apply(lambda x: x[:-n_slice] + '12:00 p.m.' if x.endswith('noon') else x)    
    df.loc[:, 'timestamp'] = df['timestamp'].apply(lambda x: x[:-m_slice] + '12:00 a.m.' if x.endswith('midnight') else x)    
    df['datetime'] = df['timestamp'].astype('datetime64[ns]')    
    
    # Trust, but always verify! 
    if _GLOBAL_DEBUG_ and _LOCAL_DEBUG_:
        print(df.info())
        print(df.head(20))
    
    return df

# %% [markdown]
# # Extracting the chat data from Slark 60 Days
#
# <br/><br/>I summon the Old Gods and The New, _EXTRACT THE DATA!_

# %%
# 1
# Get the raw list of dictionaries 
df_raw_list = extract_chat(page_content)
# 2 
# Create the DataFrame 
raw_chat_df = pd.DataFrame(df_raw_list)
# 3 
# Mild preprocessing 
chat_df = mild_preprocessing(raw_chat_df)

chat_df.info()
chat_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3406 entries, 1 to 3406
# Data columns (total 5 columns):
# message      3406 non-null object
# timestamp    3406 non-null object
# username     3406 non-null object
# m_length     3406 non-null int64
# datetime     3406 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 159.7+ KB
#                                               message             timestamp  \
# 1               \n@akshit has joined the channel\n \n  06/21/2019 4:58 p.m.
# 2      \n@aleksandra.mozejko has joined the channel\n  06/21/2019 5:07 p.m.
# 3   \n@161210032 has joined the channel\n \n@16121...  06/21/2019 5:09 p.m.
# 4   \n@ziad.esam.ezat has joined the channel\n \n@...  06/21/2019 5:26 p.m.
# 5   \n@ziad.esam.ezat No , i didn't find a way . i...  06/21/2019 5:40 p.m.
# 6   \n@rekha.chandrasekaran2 has joined the channel\n  06/21/2019 5:44 p.m.
# 7      \n@aleksandra.mozejko has joined the channel\n  06/21/2019 5:49 p.m.
# 8   \n@abhinav.raj116 has joined the channel\n \nT...  06/21/2019 6:23 p.m.
# 9             \n@rupeshpurum has joined the channel\n  06/21/2019 6:47 p.m.
# 10  \n@amatseshe has joined the channel\n \nI'm ex...  06/21/2019 6:53 p.m.
#
#                  username  m_length            datetime
# 1                  akshit        34 2019-06-21 16:58:00
# 2      aleksandra.mozejko        44 2019-06-21 17:07:00
# 3               161210032       311 2019-06-21 17:09:00
# 4          ziad.esam.ezat       234 2019-06-21 17:26:00
# 5               161210032       122 2019-06-21 17:40:00
# 6   rekha.chandrasekaran2        47 2019-06-21 17:44:00
# 7      aleksandra.mozejko        44 2019-06-21 17:49:00
# 8          abhinav.raj116       140 2019-06-21 18:23:00
# 9             rupeshpurum        37 2019-06-21 18:47:00
# 10              amatseshe        72 2019-06-21 18:53:00

# %%
# 4 
# Save the data to a CSV file 
chat_df.to_csv('./data/60_days_of_udacity_june.csv')

# %% [markdown]
# <br/><br/>Repeat the steps for July chats as well, till 13th July.

# %%
# Lets repeat the steps for extracting July Chats
with open('./data/July_13_Corpus.html', encoding='utf-8', errors='ignore') as f:
    contents = f.read()
    page_content = BeautifulSoup(contents, 'lxml')

# %%
# 1
# Get the raw list of dictionaries 
df_raw_list = extract_chat(page_content)
# 2 
# Create the DataFrame 
raw_chat_df = pd.DataFrame(df_raw_list)
# 3 
# Mild preprocessing 
chat_df = mild_preprocessing(raw_chat_df)

chat_df.info()
chat_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9612 entries, 1 to 9612
# Data columns (total 5 columns):
# message      9612 non-null object
# timestamp    9612 non-null object
# username     9612 non-null object
# m_length     9612 non-null int64
# datetime     9612 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 450.6+ KB
#                                               message             timestamp  \
# 1   \n*Day 4*\n- Finished *Lesson 5: Introducing L...  07/01/2019 5:30 a.m.
# 2                \nExcellent work :torch_heart_big:\n  07/01/2019 5:32 a.m.
# 3   \n@ahmedthabit99 thank you, and good luck with...  07/01/2019 5:37 a.m.
# 4   \n#60daysofudacity\nDay 4:\n- Studied the #rea...  07/01/2019 5:45 a.m.
# 5                \nWe are waiting your article Zik \n  07/01/2019 5:49 a.m.
# 6                 \nSure. 2 more reviews coming in.\n  07/01/2019 5:50 a.m.
# 7   \nDay 4:\n- formed a three-people group and fi...  07/01/2019 5:52 a.m.
# 8                        \nLet’s carry on to Day 5!\n  07/01/2019 6:01 a.m.
# 9                            \nwell done :clapping:\n  07/01/2019 6:08 a.m.
# 10  \nDay2/60 #60daysofudacity :\n-Finished video ...  07/01/2019 6:19 a.m.
#
#              username  m_length            datetime
# 1         suzan.hamza       378 2019-07-01 05:30:00
# 2       ahmedthabit99        34 2019-07-01 05:32:00
# 3        almaari.eman        67 2019-07-01 05:37:00
# 4        mudeledimeji       865 2019-07-01 05:45:00
# 5   george.christ1987        34 2019-07-01 05:49:00
# 6        mudeledimeji        33 2019-07-01 05:50:00
# 7          monkey-pan       213 2019-07-01 05:52:00
# 8            chan_way        26 2019-07-01 06:01:00
# 9       ahmedthabit99        22 2019-07-01 06:08:00
# 10           aajucumc       165 2019-07-01 06:19:00

# %%
# 4 
# Save the data to a CSV file 
chat_df.to_csv('./data/60_days_of_udacity_july_13.csv')

# %% [markdown]
# ## Extract participants' usernames
# This is going to be my last shenanigan, I promise!
# <br/>Let's extract the usernames of all those who are participating in the 60 Days Challenge.

# %%
lst_username = chat_df['username'].unique()

# %%
# Trust, but always verify
if _GLOBAL_DEBUG_:
    print(type(lst_username))
    print(len(lst_username))
    print(lst_username[:25])
# Out:
# <class 'numpy.ndarray'>
# 1117
# ['suzan.hamza' 'ahmedthabit99' 'almaari.eman' 'mudeledimeji'
#  'george.christ1987' 'monkey-pan' 'chan_way' 'aajucumc' 'patricklu2010'
#  'ssalvatierra777' 'naraque173' 'sfrias1' 'enrique.hz.t'
#  'dushyantpathak6789' 'carlo12david' 'adhikari.astha5' 'saulo170'
#  'adinugro' 'vipul.captureart' 'oncharijohannes' 'allangj1618' 'envshub'
#  'erinmoo' 'dinamagdhelmy' 'cclinc2005']

# %%
# Add an ampersand '@' at the start of each username 
username = ['@' + user for user in lst_username]

# %%
# Trust, but always verify
if _GLOBAL_DEBUG_:
    print(type(username))
    print(len(username))
    print(username[:25])
# Out:
# <class 'list'>
# 1117
# ['@suzan.hamza', '@ahmedthabit99', '@almaari.eman', '@mudeledimeji', '@george.christ1987', '@monkey-pan', '@chan_way', '@aajucumc', '@patricklu2010', '@ssalvatierra777', '@naraque173', '@sfrias1', '@enrique.hz.t', '@dushyantpathak6789', '@carlo12david', '@adhikari.astha5', '@saulo170', '@adinugro', '@vipul.captureart', '@oncharijohannes', '@allangj1618', '@envshub', '@erinmoo', '@dinamagdhelmy', '@cclinc2005']

# %%
# Write the data to a csv row-wise and be done with it! 
with open('./data/usernames.csv', 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    for word in username:
        wr.writerow([word])

# %% [markdown]
# _That's all folks!_
